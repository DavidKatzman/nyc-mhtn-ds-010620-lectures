# %% [markdown]
# # Import Packages

# %% [markdown]
# $Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 +  \beta_3 X_2^2 + \beta_4 log(X_3)+ \beta_5 X_1 X_2 + \beta_6 X_1 X_2^2 X_3$

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x_vals = np.array([0,.2,.4,.6,.8,1])
y_vals = 100  - 20 * x_vals
y_vals_2 = np.array([91,90,89,88,87,86])
plt.plot(x_vals, y_vals, '--')
plt.text(x_vals[1]+.1, y_vals[1]+.02, 'Agriculture')
plt.plot(x_vals, y_vals_2, '--')
plt.text(x_vals[1] - .1, y_vals_2[1] - 1, 'Metals')
plt.xlabel('Amount of Rain (Scaled)')
plt.ylabel('Commodity Price ($)')
plt.title('Affect of Rain on Commodity Prices')
plt.show()
